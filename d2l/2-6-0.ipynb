# %% [markdown]
# https://d2l.ai/chapter_preliminaries/probability.html

# %% [markdown]
# We have already invoked probabilities in previous sections without articulating what precisely they are or giving a concrete example.

# %%
# %matplotlib inline
from d2l import torch as d2l
import torch
import numpy as np
from torch.distributions import multinomial

# %%
fair_probs = torch.ones([6]) / 6
multinomial.Multinomial(1, fair_probs).sample()
# Out:
# tensor([0., 0., 1., 0., 0., 0.])

# %%
multinomial.Multinomial(10, fair_probs).sample()
# Out:
# tensor([1., 1., 1., 2., 2., 3.])

# %%
# PyTorch's Multinomial distribution doesn't offer the functionality
# for conducting multiple experiments at once. In such case we can always
# use numpy and later convert the ndarray to a torch tensor
counts = torch.from_numpy(np.random.multinomial(10, fair_probs, size=3))
counts
# Out:
# tensor([[3, 3, 2, 0, 1, 1],
#         [2, 2, 4, 1, 0, 1],
#         [2, 1, 0, 1, 4, 2]], dtype=torch.int32)

# %%
# Store the results as 32-bit floats for division
counts = multinomial.Multinomial(1000, fair_probs).sample().type(torch.float32)
counts / 1000  # Relative frequency as the estimate
# Out:
# tensor([0.1780, 0.1670, 0.1530, 0.1700, 0.1810, 0.1510])

# %%
# Store the results as 32-bit floats for division
counts = multinomial.Multinomial(1000, fair_probs).sample().type(torch.float32)
counts / 1000  # Relative frequency as the estimate
# Out:
# tensor([0.1740, 0.1530, 0.1750, 0.1720, 0.1600, 0.1660])

# %%
counts = torch.from_numpy(np.random.multinomial(10, fair_probs, size=500))
cum_counts = counts.type(torch.float32).cumsum(axis=0)
estimates = cum_counts / cum_counts.sum(axis=1, keepdims=True)

d2l.set_figsize((6, 4.5))
for i in range(6):
    d2l.plt.plot(estimates[:, i].numpy(),
                 label=("P(die=" + str(i + 1) + ")"))
d2l.plt.axhline(y=0.167, color='black', linestyle='dashed')
d2l.plt.gca().set_xlabel('Groups of experiments')
d2l.plt.gca().set_ylabel('Estimated probability')
d2l.plt.legend();

# %%
def experiment_fig(n, m):
    counts = torch.from_numpy(np.random.multinomial(n, fair_probs, size=m))
    cum_counts = counts.type(torch.float32).cumsum(axis=0)
    estimates = cum_counts / cum_counts.sum(axis=1, keepdims=True)
    d2l.set_figsize((6, 4.5))
    for i in range(6):
        d2l.plt.plot(estimates[:, i].numpy(),
                    label=("P(die=" + str(i + 1) + ")"))
    d2l.plt.axhline(y=0.167, color='black', linestyle='dashed')
    d2l.plt.gca().set_xlabel('Groups of experiments')
    d2l.plt.gca().set_ylabel('Estimated probability')
    d2l.plt.legend();

# %%
experiment_fig(30, 1000)

# %%
def experiment_fig(n, m):
    counts = torch.from_numpy(np.random.multinomial(n, fair_probs, size=m))
    cum_counts = counts.type(torch.float32).cumsum(axis=0)
    estimates = cum_counts / cum_counts.sum(axis=1, keepdims=True)
    d2l.set_figsize((6, 4.5))
    for i in range(6):
        d2l.plt.plot(estimates[:, i].numpy(),
                    label=("P(die=" + str(i + 1) + ")"))
    d2l.plt.axhline(y=0.167, color='black', linestyle='dashed')
    d2l.plt.gca().set_xlabel('Groups of experiments')
    d2l.plt.gca().set_ylabel('Estimated probability')
    d2l.plt.title(f'm = {m} groups of experiments where each group draws n = {n} samples')
    d2l.plt.legend()

# %%
experiment_fig(30, 1000)

# %%
def experiment_fig(n, m):
    counts = torch.from_numpy(np.random.multinomial(n, fair_probs, size=m))
    cum_counts = counts.type(torch.float32).cumsum(axis=0)
    estimates = cum_counts / cum_counts.sum(axis=1, keepdims=True)
    d2l.set_figsize((6, 4.5))
    for i in range(6):
        d2l.plt.plot(estimates[:, i].numpy(),
                    label=("P(die=" + str(i + 1) + ")"))
    d2l.plt.axhline(y=0.167, color='black', linestyle='dashed')
    d2l.plt.gca().set_xlabel('Groups of experiments')
    d2l.plt.gca().set_ylabel('Estimated probability')
    d2l.plt.title(f'm = {m} groups of experiments where each group draws n = {n} samples', "small")
    d2l.plt.legend()

# %%
experiment_fig(30, 1000)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-13-b6534328f358> in <module>
# ----> 1 experiment_fig(30, 1000)
#
# <ipython-input-12-8ace0d3aa191> in experiment_fig(n, m)
#      10     d2l.plt.gca().set_xlabel('Groups of experiments')
#      11     d2l.plt.gca().set_ylabel('Estimated probability')
# ---> 12     d2l.plt.title(f'm = {m} groups of experiments where each group draws n = {n} samples', "small")
#      13     d2l.plt.legend()
#
# ~\.conda\envs\pytorch\lib\site-packages\matplotlib\pyplot.py in title(label, fontdict, loc, pad, **kwargs)
#    3030 def title(label, fontdict=None, loc=None, pad=None, **kwargs):
#    3031     return gca().set_title(
# -> 3032         label, fontdict=fontdict, loc=loc, pad=pad, **kwargs)
#    3033
#    3034
#
# ~\.conda\envs\pytorch\lib\site-packages\matplotlib\axes\_axes.py in set_title(self, label, fontdict, loc, pad, **kwargs)
#     211         title.update(default)
#     212         if fontdict is not None:
# --> 213             title.update(fontdict)
#     214         title.update(kwargs)
#     215         return title
#
# ~\.conda\envs\pytorch\lib\site-packages\matplotlib\text.py in update(self, kwargs)
#     174         # Update bbox last, as it depends on font properties.
#     175         sentinel = object()  # bbox can be None, so use another sentinel.
# --> 176         bbox = kwargs.pop("bbox", sentinel)
#     177         super().update(kwargs)
#     178         if bbox is not sentinel:
#
# AttributeError: 'str' object has no attribute 'pop'

# %%
def experiment_fig(n, m):
    counts = torch.from_numpy(np.random.multinomial(n, fair_probs, size=m))
    cum_counts = counts.type(torch.float32).cumsum(axis=0)
    estimates = cum_counts / cum_counts.sum(axis=1, keepdims=True)
    d2l.set_figsize((6, 4.5))
    for i in range(6):
        d2l.plt.plot(estimates[:, i].numpy(),
                    label=("P(die=" + str(i + 1) + ")"))
    d2l.plt.axhline(y=0.167, color='black', linestyle='dashed')
    d2l.plt.gca().set_xlabel('Groups of experiments')
    d2l.plt.gca().set_ylabel('Estimated probability')
    d2l.plt.title(f'experiment groups :m = {m} groups, samples n = {n} ')
    d2l.plt.legend()

# %%
experiment_fig(30, 1000)

# %%
def experiment_fig(n, m):
    counts = torch.from_numpy(np.random.multinomial(n, fair_probs, size=m))
    cum_counts = counts.type(torch.float32).cumsum(axis=0)
    estimates = cum_counts / cum_counts.sum(axis=1, keepdims=True)
    d2l.set_figsize((6, 4.5))
    for i in range(6):
        d2l.plt.plot(estimates[:, i].numpy(),
                    label=("P(die=" + str(i + 1) + ")"))
    d2l.plt.axhline(y=0.167, color='black', linestyle='dashed')
    d2l.plt.gca().set_xlabel('Groups of experiments')
    d2l.plt.gca().set_ylabel('Estimated probability')
    d2l.plt.title(f'm (experiment groups) = {m} groups, n (samples) = {n} ')
    d2l.plt.legend()

# %%
experiment_fig(30, 1000)
