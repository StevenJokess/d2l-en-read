# %%
# %%writefile mybook/config.ini
#
# [project]
# # Specify the PDF filename to mybook.pdf
# name = mybook
# # Specify the authors names in PDF
# author = Adam Smith, Alex Li
#
# [html]
# # Add two links on the navbar. A link consists of three
# # items: name, URL, and a fontawesome icon. Items are separated by commas.
# header_links = PDF, https://book.d2l.ai/d2l-book.pdf, fas fa-file-pdf,
#                Github, https://github.com/d2l-ai/d2l-book, fab fa-github
# Out:
# Overwriting mybook/config.ini

# %%
# !cd mybook && rm -rf _build && d2lbook build html
# Out:
# [d2lbook:config.py:L12] INFO   Load configure from config.ini
# [d2lbook:build.py:L131] INFO   2 notebooks are outdated
# [d2lbook:build.py:L133] INFO   [1] ./index.md
# [d2lbook:build.py:L133] INFO   [2] ./get_started.md
# [d2lbook:build.py:L138] INFO   [1/2, 00:00:00] Evaluating ./index.md, save as _build/eval/index.ipynb
# [d2lbook:execute.py:L404] INFO   Executing notebook with kernel: python
# [d2lbook:build.py:L145] INFO   Finished in 00:00:02
# [d2lbook:build.py:L138] INFO   [2/2, 00:00:02] Evaluating ./get_started.md, save as _build/eval/get_started.ipynb
# [d2lbook:execute.py:L404] INFO   Executing notebook with kernel: python
# [d2lbook:build.py:L145] INFO   Finished in 00:00:02
# [d2lbook:build.py:L49] INFO   === Finished "d2lbook build eval" in 00:00:04
# [d2lbook:build.py:L247] INFO   2 rst files are outdated
# [d2lbook:build.py:L249] INFO   Convert _build/eval/index.ipynb to _build/rst/index.rst
# ...

# %%
# !cd mybook && d2lbook build pdf
# Out:
# [d2lbook:config.py:L12] INFO   Load configure from config.ini
# [d2lbook:build.py:L131] INFO   0 notebooks are outdated
# [d2lbook:build.py:L49] INFO   === Finished "d2lbook build eval" in 00:00:00
# [d2lbook:build.py:L247] INFO   0 rst files are outdated
# [d2lbook:build.py:L49] INFO   === Finished "d2lbook build rst" in 00:00:00
# Running Sphinx v3.4.1
# making output directory... done
# /root/mybook/mybook/_build/rst/conf.py:104: RemovedInSphinx40Warning: The app.add_javascript() is deprecated. Please use app.add_js_file() instead.
#   app.add_javascript('d2l.js')
# /root/mybook/mybook/_build/rst/conf.py:105: RemovedInSphinx40Warning: The app.add_stylesheet() is deprecated. Please use app.add_css_file() instead.
#   app.add_stylesheet('d2l.css')
# building [mo]: targets for 0 po files that are out of date
# building [latex]: all documents
# updating environment: [new config] 2 added, 0 changed, 0 removed
# reading sources... [100%] index
# ...

# %%
# !apt-get install -y latexmk
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# The following package was automatically installed and is no longer required:
#   linux-image-4.9.0-4-amd64
# Use 'apt autoremove' to remove it.
# The following additional packages will be installed:
#   adwaita-icon-theme at-spi2-core dconf-gsettings-backend dconf-service
#   fontconfig glib-networking glib-networking-common glib-networking-services
#   gsettings-desktop-schemas gtk-update-icon-cache hicolor-icon-theme
#   libatk-bridge2.0-0 libatk1.0-0 libatk1.0-data libatspi2.0-0
#   libcairo-gobject2 libcolord2 libdatrie1 libdconf1 libegl1-mesa libepoxy0
#   libgbm1 libgdk-pixbuf2.0-0 libgdk-pixbuf2.0-common libgirara-gtk3-2
#   libgtk-3-0 libgtk-3-bin libgtk-3-common libjson-c3 libjson-glib-1.0-0
#   libjson-glib-1.0-common libnotify4 libpango-1.0-0 libpangocairo-1.0-0
#   libpangoft2-1.0-0 libpoppler-glib8 libproxy1v5 librest-0.7-0 librsvg2-2
# ...

# %%
# !cd mybook && d2lbook build pdf
# Out:
# [d2lbook:config.py:L12] INFO   Load configure from config.ini
# [d2lbook:build.py:L131] INFO   0 notebooks are outdated
# [d2lbook:build.py:L49] INFO   === Finished "d2lbook build eval" in 00:00:00
# [d2lbook:build.py:L247] INFO   0 rst files are outdated
# [d2lbook:build.py:L49] INFO   === Finished "d2lbook build rst" in 00:00:00
# Running Sphinx v3.4.1
# /root/mybook/mybook/_build/rst/conf.py:104: RemovedInSphinx40Warning: The app.add_javascript() is deprecated. Please use app.add_js_file() instead.
#   app.add_javascript('d2l.js')
# /root/mybook/mybook/_build/rst/conf.py:105: RemovedInSphinx40Warning: The app.add_stylesheet() is deprecated. Please use app.add_css_file() instead.
#   app.add_stylesheet('d2l.css')
# loading pickled environment... done
# building [mo]: targets for 0 po files that are out of date
# building [latex]: all documents
# updating environment: 0 added, 0 changed, 0 removed
# looking for now-outdated files... none found
# ...

# %%
# !apt-get install -y texlive-xetex
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# The following package was automatically installed and is no longer required:
#   linux-image-4.9.0-4-amd64
# Use 'apt autoremove' to remove it.
# The following additional packages will be installed:
#   preview-latex-style texlive-generic-extra texlive-latex-extra
#   texlive-latex-extra-doc
# Suggested packages:
#   python-pygments libspreadsheet-parseexcel-perl
# The following NEW packages will be installed:
#   preview-latex-style texlive-generic-extra texlive-latex-extra
#   texlive-latex-extra-doc texlive-xetex
# 0 upgraded, 5 newly installed, 0 to remove and 0 not upgraded.
# Need to get 399 MB of archives.
# After this operation, 568 MB of additional disk space will be used.
# Get:1 http://ftp.us.debian.org/debian stretch/main amd64 preview-latex-style all 11.90-1 [200 kB]
# Get:2 http://ftp.us.debian.org/debian stretch/main amd64 texlive-generic-extra all 2016.20170123-5 [14.9 MB]
# ...

# %%
# !apt-get update && !apt-get dist-upgrade -y && !apt-get install -y python3-pip pandoc librsvg2-bin git latexmk texlive-xetex texlive-fonts-extra && apt clean
# Out:
# Get:1 http://security.debian.org/debian-security stretch/updates InRelease [53.0 kB]
# Ign:2 http://ftp.us.debian.org/debian stretch InRelease
# Hit:3 http://ftp.us.debian.org/debian stretch-updates InRelease
# Hit:4 http://ftp.us.debian.org/debian stretch Release
# Get:5 https://download.docker.com/linux/debian stretch InRelease [44.8 kB]
# Fetched 97.9 kB in 1s (54.2 kB/s)
# Reading package lists... Done
# /bin/bash: !apt-get: command not found

# %%
# !apt-get dist-upgrade -y
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# Calculating upgrade... Done
# The following package was automatically installed and is no longer required:
#   linux-image-4.9.0-4-amd64
# Use 'apt autoremove' to remove it.
# 0 upgraded, 0 newly installed, 0 to remove and 0 not upgraded.

# %%
# !apt-get install -y python3-pip pandoc librsvg2-bin git latexmk texlive-xetex texlive-fonts-extra
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# git is already the newest version (1:2.11.0-3+deb9u7).
# latexmk is already the newest version (1:4.41-1).
# texlive-xetex is already the newest version (2016.20170123-5).
# The following package was automatically installed and is no longer required:
#   linux-image-4.9.0-4-amd64
# Use 'apt autoremove' to remove it.
# The following additional packages will be installed:
#   fonts-cabin fonts-comfortaa fonts-croscore fonts-crosextra-caladea
#   fonts-crosextra-carlito fonts-dejavu-extra fonts-ebgaramond
#   fonts-ebgaramond-extra fonts-font-awesome fonts-freefont-otf
#   fonts-freefont-ttf fonts-gfs-artemisia fonts-gfs-complutum fonts-gfs-didot
#   fonts-gfs-neohellenic fonts-gfs-olga fonts-gfs-solomos fonts-junicode
#   fonts-linuxlibertine fonts-lobster fonts-lobstertwo fonts-noto-hinted
#   fonts-oflb-asana-math fonts-roboto-hinted fonts-sil-gentium
# ...

# %%
# !apt-get clean

# %%
# !cd mybook && rm -rf _build && d2lbook build html
# Out:
# [d2lbook:config.py:L12] INFO   Load configure from config.ini
# [d2lbook:build.py:L131] INFO   2 notebooks are outdated
# [d2lbook:build.py:L133] INFO   [1] ./index.md
# [d2lbook:build.py:L133] INFO   [2] ./get_started.md
# [d2lbook:build.py:L138] INFO   [1/2, 00:00:00] Evaluating ./index.md, save as _build/eval/index.ipynb
# [d2lbook:execute.py:L404] INFO   Executing notebook with kernel: python
# [d2lbook:build.py:L145] INFO   Finished in 00:00:02
# [d2lbook:build.py:L138] INFO   [2/2, 00:00:02] Evaluating ./get_started.md, save as _build/eval/get_started.ipynb
# [d2lbook:execute.py:L404] INFO   Executing notebook with kernel: python
# [d2lbook:build.py:L145] INFO   Finished in 00:00:01
# [d2lbook:build.py:L49] INFO   === Finished "d2lbook build eval" in 00:00:04
# [d2lbook:build.py:L247] INFO   2 rst files are outdated
# [d2lbook:build.py:L249] INFO   Convert _build/eval/index.ipynb to _build/rst/index.rst
# ...

# %%
# !cd mybook && d2lbook build pdf
# Out:
# [d2lbook:config.py:L12] INFO   Load configure from config.ini
# [d2lbook:build.py:L131] INFO   0 notebooks are outdated
# [d2lbook:build.py:L49] INFO   === Finished "d2lbook build eval" in 00:00:00
# [d2lbook:build.py:L247] INFO   0 rst files are outdated
# [d2lbook:build.py:L49] INFO   === Finished "d2lbook build rst" in 00:00:00
# Running Sphinx v3.4.1
# making output directory... done
# /root/mybook/mybook/_build/rst/conf.py:104: RemovedInSphinx40Warning: The app.add_javascript() is deprecated. Please use app.add_js_file() instead.
#   app.add_javascript('d2l.js')
# /root/mybook/mybook/_build/rst/conf.py:105: RemovedInSphinx40Warning: The app.add_stylesheet() is deprecated. Please use app.add_css_file() instead.
#   app.add_stylesheet('d2l.css')
# building [mo]: targets for 0 po files that are out of date
# building [latex]: all documents
# updating environment: [new config] 2 added, 0 changed, 0 removed
# reading sources... [100%] index
# ...
