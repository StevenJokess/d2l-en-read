# %% [markdown]
# https://github.com/ZhiqingXiao/rl-book/blob/master/chapter11_alphazero/TicTacToe-v0_tf.ipynb

# %%
# !pip install gym boardgame2
# Out:
# Requirement already satisfied: gym in /usr/local/lib/python3.6/dist-packages (0.17.3)
# Collecting boardgame2
#   Downloading https://files.pythonhosted.org/packages/2b/06/7b1b31862412989bf68b9554bb5ea85f36e865180442865fc0422642c805/boardgame2-0.0.5-py3-none-any.whl
# Requirement already satisfied: numpy>=1.10.4 in /usr/local/lib/python3.6/dist-packages (from gym) (1.19.4)
# Requirement already satisfied: cloudpickle<1.7.0,>=1.2.0 in /usr/local/lib/python3.6/dist-packages (from gym) (1.3.0)
# Requirement already satisfied: scipy in /usr/local/lib/python3.6/dist-packages (from gym) (1.4.1)
# Requirement already satisfied: pyglet<=1.5.0,>=1.4.0 in /usr/local/lib/python3.6/dist-packages (from gym) (1.5.0)
# Requirement already satisfied: six in /usr/local/lib/python3.6/dist-packages (from boardgame2) (1.15.0)
# Requirement already satisfied: future in /usr/local/lib/python3.6/dist-packages (from pyglet<=1.5.0,>=1.4.0->gym) (0.16.0)
# Installing collected packages: boardgame2
# Successfully installed boardgame2-0.0.5

# %%
import sys
import math
import itertools
import collections
import logging

import numpy as np
import pandas as pd
import gym
import tensorflow as tf
from tensorflow import keras

import boardgame2
from boardgame2 import BLACK, WHITE

logging.basicConfig(stream=sys.stdout, level=logging.DEBUG,
        format='%(asctime)s [%(levelname)s] %(message)s')

# %%
env = gym.make('TicTacToe-v0')

# %%
def residual(x, filters, kernel_sizes=3, strides=1, activations='relu',
            regularizer=keras.regularizers.l2(1e-4)):
    shortcut = x
    for i, filte in enumerate(filters):
        kernel_size = kernel_sizes if isinstance(kernel_sizes, int) \
                else kernel_sizes[i]
        stride = strides if isinstance(strides, int) else strides[i]
        activation = activations if isinstance(activations, str) \
                else activations[i]
        z = keras.layers.Conv2D(filte, kernel_size, strides=stride,
                padding='same', kernel_regularizer=regularizer,
                bias_regularizer=regularizer)(x)
        y = keras.layers.BatchNormalization()(z)
        if i == len(filters) - 1:
            y = keras.layers.Add()([shortcut, y])
        x = keras.layers.Activation(activation)(y)
    return x

# %%
class AlphaZeroAgent:
    def __init__(self, env, batches=1, batch_size=4096,
            kwargs={}, load=None, sim_count=800,
            c_init=1.25, c_base=19652., prior_exploration_fraction=0.25):
        self.env = env
        self.board = np.zeros_like(env.board)
        self.batches = batches
        self.batch_size = batch_size
        
        self.net = self.build_network(**kwargs)
        self.reset_mcts()
        self.sim_count = sim_count # MCTS 次数
        self.c_init = c_init # PUCT 系数
        self.c_base = c_base # PUCT 系数
        self.prior_exploration_fraction = prior_exploration_fraction
    
    
    def build_network(self, conv_filters, residual_filters, policy_filters,
            learning_rate=0.001, regularizer=keras.regularizers.l2(1e-4)):
        # 公共部分
        inputs = keras.Input(shape=self.board.shape)
        x = keras.layers.Reshape(self.board.shape + (1,))(inputs)
        for conv_filter in conv_filters:
            z = keras.layers.Conv2D(conv_filter, 3, padding='same',
                    kernel_regularizer=regularizer,
                    bias_regularizer=regularizer)(x)
            y = keras.layers.BatchNormalization()(z)
            x = keras.layers.ReLU()(y)
        for residual_filter in residual_filters:
            x = residual(x, filters=residual_filter, regularizer=regularizer)
        intermediates = x
        
        # 概率部分
        for policy_filter in policy_filters:
            z = keras.layers.Conv2D(policy_filter, 3, padding='same',
                    kernel_regularizer=regularizer,
                    bias_regularizer=regularizer)(x)
            y = keras.layers.BatchNormalization()(z)
            x = keras.layers.ReLU()(y)
        logits = keras.layers.Conv2D(1, 3, padding='same',
                kernel_regularizer=regularizer, bias_regularizer=regularizer)(x)
        flattens = keras.layers.Flatten()(logits)
        softmaxs = keras.layers.Softmax()(flattens)
        probs = keras.layers.Reshape(self.board.shape)(softmaxs)
        
        # 价值部分
        z = keras.layers.Conv2D(1, 3, padding='same',
                kernel_regularizer=regularizer,
                bias_regularizer=regularizer)(intermediates)
        y = keras.layers.BatchNormalization()(z)
        x = keras.layers.ReLU()(y)
        flattens = keras.layers.Flatten()(x)
        vs = keras.layers.Dense(1, activation=keras.activations.tanh,
                kernel_regularizer=regularizer,
                bias_regularizer=regularizer)(flattens)
        
        model = keras.Model(inputs=inputs, outputs=[probs, vs])

        def categorical_crossentropy_2d(y_true, y_pred):
            labels = tf.reshape(y_true, [-1, self.board.size])
            preds = tf.reshape(y_pred, [-1, self.board.size])
            return keras.losses.categorical_crossentropy(labels, preds)

        loss = [categorical_crossentropy_2d, keras.losses.MSE]
        optimizer = keras.optimizers.Adam(learning_rate)
        model.compile(loss=loss, optimizer=optimizer)
        return model
    
    
    def reset_mcts(self):
        def zero_board_factory(): # 用于构造 default_dict
            return np.zeros_like(self.board, dtype=float)
        self.q = collections.defaultdict(zero_board_factory)
            # q值估计: board -> board
        self.count = collections.defaultdict(zero_board_factory)
            # q值计数: board -> board
        self.policy = {} # 策略: board -> board
        self.valid = {} # 有效位置: board -> board
        self.winner = {} # 赢家: board -> None or int
    
        
    def decide(self, observation, greedy=False, return_prob=False):
        # 计算策略
        board, player = observation
        canonical_board = player * board
        s = boardgame2.strfboard(canonical_board)
        while self.count[s].sum() < self.sim_count: # 多次 MCTS 搜索
            self.search(canonical_board, prior_noise=True)
        prob = self.count[s] / self.count[s].sum()

        # 采样
        location_index = np.random.choice(prob.size, p=prob.reshape(-1))
        location = np.unravel_index(location_index, prob.shape)
        if return_prob:
            return location, prob
        return location

    def learn(self, dfs):
        df = pd.concat(dfs).reset_index(drop=True)
        for batch in range(self.batches):
            indices = np.random.choice(len(df), size=self.batch_size)
            players, boards, probs, winners = (np.stack(
                    df.loc[indices, field]) for field in df.columns)
            canonical_boards = players[:, np.newaxis, np.newaxis] * boards
            vs = (players * winners)[:, np.newaxis]
            self.net.fit(canonical_boards, [probs, vs], verbose=0) # 训练
        self.reset_mcts()
    
    
    def search(self, board, prior_noise=False): # MCTS 搜索
        s = boardgame2.strfboard(board)
        
        if s not in self.winner:
            self.winner[s] = self.env.get_winner((board, BLACK)) # 计算赢家
        if self.winner[s] is not None: # 赢家确定的情况
            return self.winner[s]
        
        if s not in self.policy: # 未计算过策略的叶子节点
            pis, vs = self.net.predict(board[np.newaxis])
            pi, v = pis[0], vs[0]
            valid = self.env.get_valid((board, BLACK))
            masked_pi = pi * valid
            total_masked_pi = np.sum(masked_pi)
            if total_masked_pi <= 0: # 所有的有效动作都没有概率，偶尔可能发生
                masked_pi = valid # workaround
                total_masked_pi = np.sum(masked_pi)
            self.policy[s] = masked_pi / total_masked_pi
            self.valid[s] = valid
            return v

        # PUCT 上界计算
        count_sum = self.count[s].sum()
        coef = (self.c_init + np.log1p((1 + count_sum) / self.c_base)) * \
                math.sqrt(count_sum) / (1. + self.count[s])
        if prior_noise: # 先验噪声
            alpha = 1. / self.valid[s].sum()
            noise = np.random.gamma(alpha, 1., board.shape)
            noise *= self.valid[s]
            noise /= noise.sum()
            prior = (1. - self.prior_exploration_fraction) * \
                    self.policy[s] + \
                    self.prior_exploration_fraction * noise
        else:
            prior = self.policy[s]
        ub = np.where(self.valid[s], self.q[s] + coef * prior, np.nan)
        location_index = np.nanargmax(ub)
        location = np.unravel_index(location_index, board.shape)
        
        (next_board, next_player), _, _, _ = self.env.next_step(
                (board, BLACK), np.array(location))
        next_canonical_board = next_player * next_board
        next_v = self.search(next_canonical_board) # 递归搜索
        v = next_player * next_v
        
        self.count[s][location] += 1
        self.q[s][location] += (v - self.q[s][location]) / \
                self.count[s][location]
        return v

# %% [markdown]
# ## 智能体和环境交互

# %%
def self_play(env, agent, return_trajectory=False, verbose=False):
    if return_trajectory:
        trajectory = []
    observation = env.reset()
    for step in itertools.count():
        board, player = observation
        action, prob = agent.decide(observation, return_prob=True)
        if verbose:
            print(boardgame2.strfboard(board))
            logging.info('第 {} 步：玩家 {}, 动作 {}'.format(step, player,
                    action))
        observation, winner, done, _ = env.step(action)
        if return_trajectory:
            trajectory.append((player, board, prob))
        if done:
            if verbose:
                print(boardgame2.strfboard(observation[0]))
                logging.info('赢家 {}'.format(winner))
            break
    if return_trajectory:
        df_trajectory = pd.DataFrame(trajectory,
                columns=['player', 'board', 'prob'])
        df_trajectory['winner'] = winner
        return df_trajectory
    else:
        return winner

# %% [markdown]
# ## 训练

# %%
"""
AlphaZero 参数，可用来求解比较大型的问题（如五子棋）
"""
train_iterations = 700000 # 训练迭代次数
train_episodes_per_iteration = 5000 # 每次迭代自我对弈回合数
batches = 10 # 每回合进行几次批学习
batch_size = 4096 # 批学习的批大小
sim_count = 800 # MCTS需要的计数
net_kwargs = {}
net_kwargs['conv_filters'] = [256,]
net_kwargs['residual_filters'] = [[256, 256],] * 19
net_kwargs['policy_filters'] = [256,]

"""
小规模参数，用来初步求解比较小的问题（如井字棋）
"""
train_iterations = 100
train_episodes_per_iteration = 100
batches = 2
batch_size = 64
sim_count = 200
net_kwargs = {}
net_kwargs['conv_filters'] = [256,]
net_kwargs['residual_filters'] = [[256, 256],]
net_kwargs['policy_filters'] = [256,]

agent = AlphaZeroAgent(env=env, kwargs=net_kwargs, sim_count=sim_count,
        batches=batches, batch_size=batch_size)


for iteration in range(train_iterations):
    # 自我对弈
    dfs_trajectory = []
    for episode in range(train_episodes_per_iteration):
        df_trajectory = self_play(env, agent,
                return_trajectory=True, verbose=False)
        logging.info('训练 {} 回合 {}: 收集到 {} 条经验'.format(
                iteration, episode, len(df_trajectory)))
        dfs_trajectory.append(df_trajectory)
    
    # 利用经验进行学习
    agent.learn(dfs_trajectory)
    logging.info('训练 {}: 学习完成'.format(iteration))
    
    # 演示训练结果
    self_play(env, agent, verbose=True)
# Out:
# 流式输出内容被截断，只能显示最后 5000 行内容。
# 2020-12-19 14:10:15,420 [INFO] 训练 69 回合 82: 收集到 8 条经验
# 2020-12-19 14:10:16,891 [INFO] 训练 69 回合 83: 收集到 7 条经验
# 2020-12-19 14:10:17,561 [INFO] 训练 69 回合 84: 收集到 9 条经验
# 2020-12-19 14:10:17,574 [INFO] 训练 69 回合 85: 收集到 9 条经验
# 2020-12-19 14:10:19,379 [INFO] 训练 69 回合 86: 收集到 9 条经验
# 2020-12-19 14:10:19,858 [INFO] 训练 69 回合 87: 收集到 9 条经验
# 2020-12-19 14:10:19,993 [INFO] 训练 69 回合 88: 收集到 6 条经验
# 2020-12-19 14:10:20,053 [INFO] 训练 69 回合 89: 收集到 9 条经验
# 2020-12-19 14:10:20,696 [INFO] 训练 69 回合 90: 收集到 7 条经验
# 2020-12-19 14:10:21,557 [INFO] 训练 69 回合 91: 收集到 8 条经验
# 2020-12-19 14:10:21,943 [INFO] 训练 69 回合 92: 收集到 9 条经验
# 2020-12-19 14:10:22,582 [INFO] 训练 69 回合 93: 收集到 7 条经验
# 2020-12-19 14:10:23,089 [INFO] 训练 69 回合 94: 收集到 9 条经验
# 2020-12-19 14:10:24,534 [INFO] 训练 69 回合 95: 收集到 9 条经验
# 2020-12-19 14:10:27,815 [INFO] 训练 69 回合 96: 收集到 9 条经验
# 2020-12-19 14:10:28,553 [INFO] 训练 69 回合 97: 收集到 7 条经验
# 2020-12-19 14:10:29,257 [INFO] 训练 69 回合 98: 收集到 5 条经验
# 2020-12-19 14:10:29,322 [INFO] 训练 69 回合 99: 收集到 8 条经验
# 2020-12-19 14:10:29,466 [INFO] 训练 69: 学习完成
# +++
# +++
# +++
# 2020-12-19 14:10:35,828 [INFO] 第 0 步：玩家 1, 动作 (0, 0)
# o++
# +++
# +++
# 2020-12-19 14:10:40,181 [INFO] 第 1 步：玩家 -1, 动作 (0, 2)
# o+x
# +++
# +++
# 2020-12-19 14:10:43,825 [INFO] 第 2 步：玩家 1, 动作 (1, 0)
# o+x
# o++
# +++
# 2020-12-19 14:10:44,492 [INFO] 第 3 步：玩家 -1, 动作 (2, 0)
# o+x
# o++
# x++
# 2020-12-19 14:10:44,816 [INFO] 第 4 步：玩家 1, 动作 (1, 1)
# o+x
# oo+
# x++
# 2020-12-19 14:10:44,834 [INFO] 第 5 步：玩家 -1, 动作 (2, 1)
# o+x
# oo+
# xx+
# 2020-12-19 14:10:44,895 [INFO] 第 6 步：玩家 1, 动作 (1, 2)
# o+x
# ooo
# xx+
# 2020-12-19 14:10:44,902 [INFO] 赢家 1
# 2020-12-19 14:10:52,144 [INFO] 训练 70 回合 0: 收集到 5 条经验
# 2020-12-19 14:10:55,605 [INFO] 训练 70 回合 1: 收集到 9 条经验
# 2020-12-19 14:11:03,501 [INFO] 训练 70 回合 2: 收集到 9 条经验
# 2020-12-19 14:11:09,751 [INFO] 训练 70 回合 3: 收集到 8 条经验
# 2020-12-19 14:11:10,299 [INFO] 训练 70 回合 4: 收集到 7 条经验
# 2020-12-19 14:11:17,513 [INFO] 训练 70 回合 5: 收集到 6 条经验
# 2020-12-19 15:20:06,001 [INFO] 训练 98 回合 97: 收集到 7 条经验
# 2020-12-19 15:20:06,075 [INFO] 训练 98 回合 98: 收集到 6 条经验
# 2020-12-19 15:20:06,208 [INFO] 训练 98 回合 99: 收集到 9 条经验
# 2020-12-19 15:20:06,356 [INFO] 训练 98: 学习完成
# +++
# +++
# +++
# 2020-12-19 15:20:12,804 [INFO] 第 0 步：玩家 1, 动作 (1, 1)
# +++
# +o+
# +++
# 2020-12-19 15:20:17,193 [INFO] 第 1 步：玩家 -1, 动作 (0, 0)
# x++
# +o+
# +++
# 2020-12-19 15:20:21,347 [INFO] 第 2 步：玩家 1, 动作 (1, 0)
# x++
# oo+
# +++
# 2020-12-19 15:20:22,136 [INFO] 第 3 步：玩家 -1, 动作 (1, 2)
# x++
# oox
# +++
# 2020-12-19 15:20:22,249 [INFO] 第 4 步：玩家 1, 动作 (0, 2)
# x+o
# oox
# +++
# 2020-12-19 15:20:22,512 [INFO] 第 5 步：玩家 -1, 动作 (2, 0)
# x+o
# oox
# x++
# 2020-12-19 15:20:22,553 [INFO] 第 6 步：玩家 1, 动作 (2, 1)
# x+o
# oox
# xo+
# 2020-12-19 15:20:22,703 [INFO] 第 7 步：玩家 -1, 动作 (0, 1)
# xxo
# oox
# xo+
# 2020-12-19 15:20:22,705 [INFO] 第 8 步：玩家 1, 动作 (2, 2)
# xxo
# oox
# xoo
# 2020-12-19 15:20:22,709 [INFO] 赢家 0
# 2020-12-19 15:20:29,612 [INFO] 训练 99 回合 0: 收集到 5 条经验
# 2020-12-19 15:20:35,904 [INFO] 训练 99 回合 1: 收集到 9 条经验
# 2020-12-19 15:20:40,964 [INFO] 训练 99 回合 2: 收集到 7 条经验
# 2020-12-19 15:20:48,409 [INFO] 训练 99 回合 3: 收集到 9 条经验
# 2020-12-19 15:20:48,416 [INFO] 训练 99 回合 4: 收集到 9 条经验
# 2020-12-19 15:20:52,541 [INFO] 训练 99 回合 5: 收集到 9 条经验
# 2020-12-19 15:20:53,156 [INFO] 训练 99 回合 6: 收集到 9 条经验
# 2020-12-19 15:20:54,011 [INFO] 训练 99 回合 7: 收集到 9 条经验
# 2020-12-19 15:20:59,321 [INFO] 训练 99 回合 8: 收集到 9 条经验
# 2020-12-19 15:21:03,984 [INFO] 训练 99 回合 9: 收集到 9 条经验
# 2020-12-19 15:21:08,744 [INFO] 训练 99 回合 10: 收集到 9 条经验
# 2020-12-19 15:21:10,243 [INFO] 训练 99 回合 11: 收集到 7 条经验
# 2020-12-19 15:21:10,834 [INFO] 训练 99 回合 12: 收集到 9 条经验
# 2020-12-19 15:21:11,578 [INFO] 训练 99 回合 13: 收集到 9 条经验
# 2020-12-19 15:21:12,036 [INFO] 训练 99 回合 14: 收集到 9 条经验
# 2020-12-19 15:21:13,514 [INFO] 训练 99 回合 15: 收集到 8 条经验
# 2020-12-19 15:21:15,000 [INFO] 训练 99 回合 16: 收集到 5 条经验
# 2020-12-19 15:21:15,007 [INFO] 训练 99 回合 17: 收集到 9 条经验
# 2020-12-19 15:22:18,435 [INFO] 训练 99 回合 87: 收集到 9 条经验
# 2020-12-19 15:22:19,315 [INFO] 训练 99 回合 88: 收集到 7 条经验
# 2020-12-19 15:22:20,152 [INFO] 训练 99 回合 89: 收集到 5 条经验
# 2020-12-19 15:22:20,218 [INFO] 训练 99 回合 90: 收集到 7 条经验
# 2020-12-19 15:22:20,226 [INFO] 训练 99 回合 91: 收集到 9 条经验
# 2020-12-19 15:22:20,563 [INFO] 训练 99 回合 92: 收集到 7 条经验
# 2020-12-19 15:22:20,569 [INFO] 训练 99 回合 93: 收集到 9 条经验
# 2020-12-19 15:22:21,663 [INFO] 训练 99 回合 94: 收集到 5 条经验
# 2020-12-19 15:22:21,670 [INFO] 训练 99 回合 95: 收集到 9 条经验
# 2020-12-19 15:22:22,112 [INFO] 训练 99 回合 96: 收集到 9 条经验
# 2020-12-19 15:22:22,305 [INFO] 训练 99 回合 97: 收集到 5 条经验
# 2020-12-19 15:22:23,435 [INFO] 训练 99 回合 98: 收集到 9 条经验
# 2020-12-19 15:22:23,665 [INFO] 训练 99 回合 99: 收集到 5 条经验
# 2020-12-19 15:22:23,805 [INFO] 训练 99: 学习完成
# +++
# +++
# +++
# 2020-12-19 15:22:29,977 [INFO] 第 0 步：玩家 1, 动作 (0, 2)
# ++o
# +++
# +++
# 2020-12-19 15:22:34,935 [INFO] 第 1 步：玩家 -1, 动作 (1, 0)
# ++o
# x++
# +++
# 2020-12-19 15:22:37,002 [INFO] 第 2 步：玩家 1, 动作 (1, 2)
# ++o
# x+o
# +++
# 2020-12-19 15:22:39,008 [INFO] 第 3 步：玩家 -1, 动作 (2, 2)
# ++o
# x+o
# ++x
# 2020-12-19 15:22:39,351 [INFO] 第 4 步：玩家 1, 动作 (0, 0)
# o+o
# x+o
# ++x
# 2020-12-19 15:22:39,523 [INFO] 第 5 步：玩家 -1, 动作 (2, 0)
# o+o
# x+o
# x+x
# 2020-12-19 15:22:39,599 [INFO] 第 6 步：玩家 1, 动作 (0, 1)
# ooo
# x+o
# x+x
# 2020-12-19 15:22:39,600 [INFO] 赢家 1

# %%
self_play(env, agent, verbose=True)
# Out:
# +++
# +++
# +++
# 2020-12-19 15:22:39,613 [INFO] 第 0 步：玩家 1, 动作 (2, 2)
# +++
# +++
# ++o
# 2020-12-19 15:22:44,129 [INFO] 第 1 步：玩家 -1, 动作 (0, 0)
# x++
# +++
# ++o
# 2020-12-19 15:22:46,883 [INFO] 第 2 步：玩家 1, 动作 (0, 2)
# x+o
# +++
# ++o
# 2020-12-19 15:22:47,067 [INFO] 第 3 步：玩家 -1, 动作 (1, 0)
# x+o
# x++
# ++o
# 2020-12-19 15:22:47,236 [INFO] 第 4 步：玩家 1, 动作 (2, 1)
# x+o
# x++
# +oo
# 2020-12-19 15:22:47,426 [INFO] 第 5 步：玩家 -1, 动作 (2, 0)
# x+o
# x++
# xoo
# 2020-12-19 15:22:47,427 [INFO] 赢家 -1
# -1
